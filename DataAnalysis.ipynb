# %%
import pymysql
import pprint
db = pymysql.connect(
                host="localhost",
                port=3306,
                user="root",
                passwd="pass",
                db="keeper",
                charset="utf8",
            )


try:
    sql = (
        """
        select * from datainfo
        """
        #%()
    )
    cursor = db.cursor()
    cursor.execute(sql)
    result = cursor.fetchall()
    pprint.pprint(result)
except Exception:
    print("error")
    
db.close();
# Out:
# ((5,
#   datetime.datetime(2020, 6, 26, 12, 59, 58),
#   'dD4eckdGhwdTClsU',
#   'Blockchain',
#   'What is AI',
#   '0x78658C9AaD8523BB283029C43135CF87339ADC21',
#   '0x7161a4eCE5dD841756ee38cBEa7da055F29302c9',
#   1),
#  (5,
#   datetime.datetime(2020, 6, 26, 13, 10, 25),
#   'Evap96NltJXpar88',
#   'Blockchain',
#   'What is AI',
#   '0x0000000000000000000000000000000000000000',
#   '0x7161a4eCE5dD841756ee38cBEa7da055F29302c9',
#   0),
#  (5,
#   datetime.datetime(2020, 6, 26, 13, 11, 41),
#   'GtczePj4Jyf4jUqa',
#   'Weather',
#   'Good weather',
#   '0x78658C9AaD8523BB283029C43135CF87339ADC21',
#   '0x7161a4eCE5dD841756ee38cBEa7da055F29302c9',
#   1),
#  (10,
#   datetime.datetime(2020, 6, 26, 13, 6, 7),
#   'Ilm4Vj0q0ueXZVFf',
#   'Weather',
#   'Winter is Comming',
#   '0x0000000000000000000000000000000000000000',
#   '0x7161a4eCE5dD841756ee38cBEa7da055F29302c9',
#   0),
#  (10,
#   datetime.datetime(2020, 6, 26, 13, 12, 3),
#   'izQEr14kCwaDDrre',
#   'Health',
# ...
